# %%
import pandas as pd
reviews = pd.read_csv("Amazon_reviews_sample.csv")
reviews= reviews[0:100]
reviews.shape
# Out:
# (100, 3)

# %%
# Import the needed packages
from nltk import word_tokenize

# Tokenize each item in the review column 
word_tokens = [word_tokenize(review) for review in reviews.review]

# Print out the first item of the word_tokens list
print(word_tokens[0])
# Out:
# ['Stuning', 'even', 'for', 'the', 'non-gamer', ':', 'This', 'sound', 'track', 'was', 'beautiful', '!', 'It', 'paints', 'the', 'senery', 'in', 'your', 'mind', 'so', 'well', 'I', 'would', 'recomend', 'it', 'even', 'to', 'people', 'who', 'hate', 'vid', '.', 'game', 'music', '!', 'I', 'have', 'played', 'the', 'game', 'Chrono', 'Cross', 'but', 'out', 'of', 'all', 'of', 'the', 'games', 'I', 'have', 'ever', 'played', 'it', 'has', 'the', 'best', 'music', '!', 'It', 'backs', 'away', 'from', 'crude', 'keyboarding', 'and', 'takes', 'a', 'fresher', 'step', 'with', 'grate', 'guitars', 'and', 'soulful', 'orchestras', '.', 'It', 'would', 'impress', 'anyone', 'who', 'cares', 'to', 'listen', '!', '^_^']

# %%
len(word_tokens)
# Out:
# 100

# %%
# Create an empty list to store the length of reviews
len_tokens = []

# Iterate over the word_tokens list and determine the length of each item
for i in range(len(word_tokens)):
     len_tokens.append(len(word_tokens[i]))

# Create a new feature for the lengh of each review
reviews['n_words'] = len_tokens

# %%
reviews
# Out:
#     Unnamed: 0  score                                             review  \
# 0            0      1   Stuning even for the non-gamer: This sound tr...
# 1            1      1   The best soundtrack ever to anything.: I'm re...
# 2            2      1   Amazing!: This soundtrack is my favorite musi...
# 3            3      1   Excellent Soundtrack: I truly like this sound...
# 4            4      1   Remember, Pull Your Jaw Off The Floor After H...
# 5            5      1   an absolute masterpiece: I am quite sure any ...
# 6            6      0   Buyer beware: This is a self-published book, ...
# 7            7      1   Glorious story: I loved Whisper of the wicked...
# 8            8      1   A FIVE STAR BOOK: I just finished reading Whi...
# 9            9      1   Whispers of the Wicked Saints: This was a eas...
# 10          10      0   The Worst!: A complete waste of time. Typogra...
# 11          11      1   Great book: This was a great book,I just coul...
# 12          12      1   Great Read: I thought this book was brilliant...
# 13          13      0   Oh please: I guess you have to be a romance n...
# 14          14      0   Awful beyond belief!: I feel I have to write ...
# 15          15      0   Don't try to fool us with fake reviews.: It's...
# 16          16      1   A romantic zen baseball comedy: When you hear...
# 17          17      1   Fashionable Compression Stockings!: After I h...
# 18          18      1   Jobst UltraSheer Thigh High: Excellent produc...
# 19          19      0   sizes recomended in the size chart are not re...
# 20          20      0   mens ultrasheer: This model may be ok for sed...
# 21          21      1   Delicious cookie mix: I thought it was funny ...
# 22          22      0   Another Abysmal Digital Copy: Rather than scr...
# 23          23      1   A fascinating insight into the life of modern...
# 24          24      1   i liked this album more then i thought i woul...
# 25          25      0   Problem with charging smaller AAAs: I have ha...
# 26          26      0   Works, but not as advertised: I bought one of...
# 27          27      0   Disappointed: I read the reviews,made my purc...
# 28          28      0   Oh dear: I was excited to find a book ostensi...
# 29          29      1   Based on the reviews here I bought one and I'...
# ..         ...    ...                                                ...
# 70          70      0   [Not what I expected]: ... My daughter and I ...
# 71          71      0   barbie rapunzel = crying child: My 6-year old...
# 72          72      1   Barbie as Rapunzel: A Creative Adventure: I p...
# 73          73      1   Use your imagination!: My 3 year old daughter...
# 74          74      0   Not so good - ok for a rental!: This game is ...
# 75          75      0   NOT OS X but MAC CLASSIC: NEGATIVE: This game...
# 76          76      0   Bad Deal!!: I ordered this DVD and received a...
# 77          77      1   Smells divine.: This is my second bottle of s...
# 78          78      0   Very disappointed!: This perfume is just AWFU...
# 79          79      1   Creepy: Wow, what people will do behind jealo...
# 80          80      0   audio options non existent: While the movie i...
# 81          81      1   Sooo JAMMIN', too trill: Man, some more jammi...
# 82          82      1   Dirty South: This is probably the best souths...
# 83          83      1   Good book: Well written chronicles of The Far...
# 84          84      1   voices from the farm: i have a copy of this b...
# 85          85      1   Little one, maid of Israel: Bill Harvey has a...
# 86          86      0   It Drew Air: This book drew air pretty bad. I...
# 87          87      1   comfy,warm.. but run big: just like the title...
# 88          88      0   Buyer Beware!!: I ordered the cake topper Jun...
# 89          89      0   Ariel Litte Mermaid with pearl kit: Arrived v...
# 90          90      0   No instructions included - do not trust selle...
# 91          91      1   Why is SOULWAX ignored by critics & consumers...
# 92          92      1   OMG Soulwax owns: wow - this is like the most...
# 93          93      0   Slow dull "classical" 1980's style movie: 2 s...
# 94          94      1   Thank you for Releasing it!!!!!: I loved this...
# 95          95      0   Very Not Worth Your Time: The book was wriite...
# 96          96      1   Very fun and educational: Trains, shapes and ...
# 97          97      0   Ludicrous and silly: I remember getting this ...
# 98          98      1   Artistry: I think that the Deodato concerts a...
# 99          99      0   Caution!: These tracks are not the "original"...
#
#     n_words
# 0        87
# 1       109
# 2       165
# 3       145
# 4       109
# 5       169
# 6       168
# 7       117
# 8       113
# 9        70
# 10       43
# 11      109
# 12       66
# 13      108
# 14      151
# 15       61
# 16      135
# 17      132
# 18       83
# 19       53
# 20       87
# 21      182
# 22      187
# 23      155
# 24       65
# 25      132
# 26      118
# 27       57
# 28      119
# 29      187
# ..      ...
# 70       82
# 71      204
# 72       55
# 73      159
# 74      132
# 75      134
# 76      142
# 77       32
# 78       30
# 79       36
# 80      143
# 81      200
# 82       63
# 83       44
# 84       29
# 85       75
# 86       36
# 87       48
# 88      131
# 89       75
# 90      114
# 91      187
# 92       76
# 93       92
# 94       49
# 95       62
# 96       36
# 97       40
# 98       35
# 99       31
#
# [100 rows x 4 columns]
